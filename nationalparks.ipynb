# %% [markdown]
# # U.S. National Parks

# %%
import pandas as pd
import geopandas as gpd
import json

# %%
data = pd.read_json('data.json')
data
# Out:
#                                                  area  \
# 0        {'acres': '49,057.36', 'square_km': '198.5'}
# 1          {'acres': '8,256.67', 'square_km': '33.4'}
# 2        {'acres': '76,678.98', 'square_km': '310.3'}
# 3       {'acres': '242,755.94', 'square_km': '982.4'}
# 4     {'acres': '801,163.21', 'square_km': '3,242.2'}
# 5       {'acres': '172,971.11', 'square_km': '700.0'}
# 6        {'acres': '30,749.75', 'square_km': '124.4'}
# 7        {'acres': '35,835.08', 'square_km': '145.0'}
# 8     {'acres': '337,597.83', 'square_km': '1,366.2'}
# 9       {'acres': '241,904.26', 'square_km': '979.0'}
# 10       {'acres': '46,766.45', 'square_km': '189.3'}
# 11    {'acres': '249,561.00', 'square_km': '1,009.9'}
# 12       {'acres': '26,275.82', 'square_km': '106.3'}
# 13      {'acres': '183,224.05', 'square_km': '741.5'}
# 14       {'acres': '32,572.35', 'square_km': '131.8'}
# 15  {'acres': '3,373,063.14', 'square_km': '13,650...
# ...

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   area                       59 non-null     object
#  1   coordinates                59 non-null     object
#  2   date_established_readable  59 non-null     object
#  3   date_established_unix      59 non-null     int64
#  4   description                59 non-null     object
#  5   image                      59 non-null     object
#  6   nps_link                   59 non-null     object
#  7   states                     59 non-null     object
#  8   title                      59 non-null     object
#  9   id                         59 non-null     object
#  10  visitors                   59 non-null     object
#  11  world_heritage_site        59 non-null     bool
# dtypes: bool(1), int64(1), object(10)
# memory usage: 5.3+ KB

# %%
data.to_file("data/data.geoJSON", driver="GeoJSON")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-ec1c20434c3c> in <module>
# ----> 1 data.to_file("data/data.geoJSON", driver="GeoJSON")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_file'
